# %%
import numpy as np
import pandas as pd

# %%
jan_trip = pd.read_parquet(r"C:\Users\ditri\Desktop\Important\Data\Misra Turp New York Taxi Portfolio Project\yellow_tripdata_2024-01.parquet", engine = 'pyarrow')

# %%
jan_trip.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee'],
#       dtype='object')

# %%
jan_trip.shape
# Out:
# (2964624, 19)

# %%
jan_trip.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2024-01-01 00:57:55   2024-01-01 01:17:43              1.0
# 1         1  2024-01-01 00:03:00   2024-01-01 00:09:36              1.0
# 2         1  2024-01-01 00:17:06   2024-01-01 00:35:01              1.0
# 3         1  2024-01-01 00:36:38   2024-01-01 00:44:56              1.0
# 4         1  2024-01-01 00:46:51   2024-01-01 00:52:57              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0           1.72         1.0                  N           186            79
# 1           1.80         1.0                  N           140           236
# 2           4.70         1.0                  N           236            79
# 3           1.40         1.0                  N            79           211
# 4           0.80         1.0                  N           211           148
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# ...

# %%
jan_trip.dtypes
# Out:
# VendorID                          int32
# tpep_pickup_datetime     datetime64[us]
# tpep_dropoff_datetime    datetime64[us]
# passenger_count                 float64
# trip_distance                   float64
# RatecodeID                      float64
# store_and_fwd_flag               object
# PULocationID                      int32
# DOLocationID                      int32
# payment_type                      int64
# fare_amount                     float64
# extra                           float64
# mta_tax                         float64
# tip_amount                      float64
# tolls_amount                    float64
# improvement_surcharge           float64
# total_amount                    float64
# congestion_surcharge            float64
# Airport_fee                     float64
# dtype: object

# %%
jan_trip.isna().sum()
# Out:
# VendorID                      0
# tpep_pickup_datetime          0
# tpep_dropoff_datetime         0
# passenger_count          140162
# trip_distance                 0
# RatecodeID               140162
# store_and_fwd_flag       140162
# PULocationID                  0
# DOLocationID                  0
# payment_type                  0
# fare_amount                   0
# extra                         0
# mta_tax                       0
# tip_amount                    0
# tolls_amount                  0
# improvement_surcharge         0
# total_amount                  0
# congestion_surcharge     140162
# Airport_fee              140162
# dtype: int64

# %%
jan_trip[jan_trip['passenger_count'].isna()].head()
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 2824462         2  2024-01-01 00:34:19   2024-01-01 00:51:22              NaN
# 2824463         1  2024-01-01 00:14:31   2024-01-01 00:19:29              NaN
# 2824464         1  2024-01-01 00:35:11   2024-01-01 01:13:40              NaN
# 2824465         1  2024-01-01 00:33:37   2024-01-01 00:50:34              NaN
# 2824466         1  2024-01-01 00:49:04   2024-01-01 01:01:16              NaN
#
#          trip_distance  RatecodeID store_and_fwd_flag  PULocationID  \
# 2824462           2.04         NaN               None           143
# 2824463           1.60         NaN               None           236
# 2824464           0.00         NaN               None           142
# 2824465           0.00         NaN               None           237
# 2824466           0.00         NaN               None           244
#
#          DOLocationID  payment_type  fare_amount  extra  mta_tax  tip_amount  \
# ...

# %%
jan_trip.duplicated().sum()
# Out:
# np.int64(0)
